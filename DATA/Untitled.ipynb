# %%
import pandas as pd
pd.set_option('display.max_rows', 10000)
pd.options.display.max_seq_items = 10000

# %%
df = pd.read_csv('taxi_data.csv')
df = df.iloc[:5000,:]

# %%
row_list = []
for index, rows in df.iterrows(): 
    my_list = (rows.vendor_id,
 rows.tpep_pickup_datetime,
 rows.tpep_dropoff_datetime,
 rows.passenger_count,
 rows.trip_distance,
 rows.pickup_longitude,
 rows.pickup_latitude,
 rows.rate_code_id,
 rows.store_and_fwd_flag,
 rows.dropoff_longitude,
 rows.dropoff_latitude,
 rows.payment_type,
 rows.fare_amount,
 rows.extra,
 rows.mta_tax,
 rows.tip_amount,
 rows.tolls_amount,
 rows.improvement_surcharge,
 rows.total_amount)
    row_list.append(my_list)

row_list
# Out:
# [(1,
#   '2016-06-01 00:00:00-04',
#   '2016-06-01 00:07:41-04',
#   1,
#   1.3,
#   -74.0084457397461,
#   40.70602416992188,
#   1,
#   'N',
#   -74.01338958740234,
#   40.70964431762695,
#   1,
#   7.5,
#   0.5,
#   0.5,
#   2.6,
#   0.0,
#   0.3,
#   11.4),
#  (1,
#   '2016-06-01 00:00:00-04',
#   '2016-06-01 00:15:25-04',
#   1,
#   5.9,
#   -73.96222686767578,
#   40.76063537597656,
#   1,
#   'N',
#   -73.92228698730467,
#   40.82721328735352,
#   1,
#   19.5,
#   0.5,
#   0.5,
#   4.16,
#   0.0,
#   0.3,
#   24.96),
#  (1,
#   '2016-06-01 00:00:00-04',
#   '2016-06-01 00:14:11-04',
#   4,
#   2.3,
#   -73.97291564941406,
#   40.7549934387207,
#   1,
#   'N',
#   -73.99226379394531,
#   40.725242614746094,
#   1,
#   11.5,
#   0.5,
#   0.5,
#   3.8,
#   0.0,
#   0.3,
#   16.6),
#  (2,
#   '2016-06-01 00:00:00-04',
#   '2016-06-01 00:00:00-04',
#   1,
#   2.59,
#   -73.9975051879883,
#   40.725486755371094,
#   1,
#   'N',
#   -73.99774169921875,
#   40.74491882324219,
#   2,
# ...

# %%
df.head(15)
# Out:
#     vendor_id    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0           1  2016-06-01 00:00:00-04  2016-06-01 00:07:41-04
# 1           1  2016-06-01 00:00:00-04  2016-06-01 00:15:25-04
# 2           1  2016-06-01 00:00:00-04  2016-06-01 00:14:11-04
# 3           2  2016-06-01 00:00:00-04  2016-06-01 00:00:00-04
# 4           1  2016-06-01 00:00:01-04  2016-06-01 00:03:44-04
# 5           1  2016-06-01 00:00:01-04  2016-06-01 00:06:17-04
# 6           2  2016-06-01 00:00:01-04  2016-06-01 00:03:00-04
# 7           2  2016-06-01 00:00:02-04  2016-06-01 00:08:20-04
# 8           2  2016-06-01 00:00:02-04  2016-06-01 00:03:45-04
# 9           1  2016-06-01 00:00:03-04  2016-06-01 00:05:24-04
# 10          2  2016-06-01 00:00:03-04  2016-06-01 00:22:02-04
# 11          2  2016-06-01 00:00:03-04  2016-06-01 00:06:11-04
# 12          1  2016-06-01 00:00:05-04  2016-06-01 00:00:07-04
# 13          2  2016-06-01 00:00:05-04  2016-06-01 00:07:00-04
# ...

# %%
lst = ['rows.'+ i for i in df.columns]

# %%
lst
# Out:
# ['rows.vendor_id',
#  'rows.tpep_pickup_datetime',
#  'rows.tpep_dropoff_datetime',
#  'rows.passenger_count',
#  'rows.trip_distance',
#  'rows.pickup_longitude',
#  'rows.pickup_latitude',
#  'rows.rate_code_id',
#  'rows.store_and_fwd_flag',
#  'rows.dropoff_longitude',
#  'rows.dropoff_latitude',
#  'rows.payment_type',
#  'rows.fare_amount',
#  'rows.extra',
#  'rows.mta_tax',
#  'rows.tip_amount',
#  'rows.tolls_amount',
#  'rows.improvement_surcharge',
#  'rows.total_amount']
